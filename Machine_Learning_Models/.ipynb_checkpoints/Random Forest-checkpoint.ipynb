# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
training_df = pd.read_csv('../train.csv')
training_df.set_index('Timestamp', inplace=True)
training_df.drop(['Country', 'Ad Topic Line'], axis=1, inplace=True)
training_df.head()
# Out:
#                      Daily Time Spent on Site       Age  Area Income  \
# Timestamp
# 2016-01-29 00:45:19                 -1.003266 -0.475928    -1.074513
# 2016-01-05 20:58:42                  0.838468  0.211953     0.176047
# 2016-06-18 16:02:34                 -1.895712  0.441247    -0.705899
# 2016-06-21 00:52:47                  0.386877 -0.705222     1.065619
# 2016-04-17 05:08:52                  1.199110  1.358422    -0.643565
#
#                      Daily Internet Usage  Afghanistan  Albania  Algeria  \
# Timestamp
# 2016-01-29 00:45:19             -1.369008            0        0        0
# 2016-01-05 20:58:42              1.637189            0        0        0
# 2016-06-18 16:02:34             -0.666237            0        0        0
# 2016-06-21 00:52:47              1.014610            0        0        0
# 2016-04-17 05:08:52             -1.009855            0        0        0
#
#                      American Samoa  Andorra  Angola  ...  Yemen  Zambia  \
# Timestamp                                             ...
# 2016-01-29 00:45:19               0        0       0  ...      0       0
# 2016-01-05 20:58:42               0        0       0  ...      0       0
# 2016-06-18 16:02:34               0        0       0  ...      0       0
# 2016-06-21 00:52:47               0        0       0  ...      0       0
# 2016-04-17 05:08:52               0        0       0  ...      0       0
#
#                      Zimbabwe  afternoon  evening  morning  night  \
# Timestamp
# 2016-01-29 00:45:19         0          0        0        0      1
# 2016-01-05 20:58:42         0          0        1        0      0
# 2016-06-18 16:02:34         0          1        0        0      0
# 2016-06-21 00:52:47         0          0        0        0      1
# 2016-04-17 05:08:52         0          0        0        1      0
#
#                      Ad Line Length  Ad Line Word Length  Clicked on Ad
# Timestamp
# 2016-01-29 00:45:19       -0.247760            -0.451417              1
# 2016-01-05 20:58:42        0.629266             3.723539              0
# 2016-06-18 16:02:34        3.611156             1.636061              1
# 2016-06-21 00:52:47       -0.773976            -0.451417              0
# 2016-04-17 05:08:52       -1.475597            -0.451417              1
#
# [5 rows x 245 columns]

# %%
X = training_df.loc[:, 'Daily Time Spent on Site': 'Ad Line Word Length']
y = training_df['Clicked on Ad']

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
param_grid = [
    {
        'max_features': ['auto', 'sqrt'], 
        'n_estimators': [100, 250, 500, 1000],
        'min_impurity_decrease': [0.0, 1e-7]
    }
]

# %%
cv_len = 5

rgc_grid_search = GridSearchCV(rfc, param_grid, cv=cv_len, scoring='accuracy', refit='accuracy')

# %%
rgc_grid_search.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_features': ['auto', 'sqrt'],
#                           'min_impurity_decrease': [0.0, 1e-07],
#                           'n_estimators': [100, 250, 500, 1000]}],
#              pre_dispatch='2*n_jobs', refit='accuracy',
#              return_train_score=False, scoring='accuracy', verbose=0)

# %%
rgc_grid_search.cv_results_
# Out:
# {'mean_fit_time': array([0.11536646, 0.27091198, 0.50846186, 1.01881695, 0.11665382,
#         0.28865962, 0.53671913, 1.0812006 , 0.10654373, 0.26709228,
#         0.52920551, 1.07382164, 0.11110945, 0.27748146, 0.55479646,
#         1.10554919]),
#  'std_fit_time': array([0.01784613, 0.01885782, 0.00501521, 0.01283366, 0.00689799,
#         0.01088642, 0.01667716, 0.06332004, 0.00259349, 0.00393609,
#         0.00616651, 0.01188008, 0.00190297, 0.00700874, 0.01793635,
#         0.0102333 ]),
#  'mean_score_time': array([0.00901341, 0.01826901, 0.03478642, 0.06993322, 0.00919695,
#         0.02152853, 0.03614979, 0.08044653, 0.00822062, 0.01814141,
#         0.03593302, 0.07281113, 0.00851636, 0.01869721, 0.03679934,
#         0.07314038]),
#  'std_score_time': array([1.11622559e-03, 2.75541886e-04, 2.43013142e-04, 1.22478023e-03,
#         4.14152971e-04, 2.81052885e-03, 1.58955796e-03, 1.84983551e-02,
#         9.23166344e-05, 2.64448643e-04, 8.06112516e-04, 1.07412636e-03,
#         2.39692309e-04, 9.12117611e-04, 1.48063897e-03, 2.54164293e-03]),
#  'param_max_features': masked_array(data=['auto', 'auto', 'auto', 'auto', 'auto', 'auto', 'auto',
#                     'auto', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'sqrt',
#                     'sqrt', 'sqrt'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_impurity_decrease': masked_array(data=[0.0, 0.0, 0.0, 0.0, 1e-07, 1e-07, 1e-07, 1e-07, 0.0,
#                     0.0, 0.0, 0.0, 1e-07, 1e-07, 1e-07, 1e-07],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 250, 500, 1000, 100, 250, 500, 1000, 100, 250,
#                     500, 1000, 100, 250, 500, 1000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_features': 'auto',
#    'min_impurity_decrease': 0.0,
#    'n_estimators': 100},
#   {'max_features': 'auto', 'min_impurity_decrease': 0.0, 'n_estimators': 250},
#   {'max_features': 'auto', 'min_impurity_decrease': 0.0, 'n_estimators': 500},
#   {'max_features': 'auto', 'min_impurity_decrease': 0.0, 'n_estimators': 1000},
#   {'max_features': 'auto',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 100},
#   {'max_features': 'auto',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 250},
#   {'max_features': 'auto',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 500},
#   {'max_features': 'auto',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 1000},
#   {'max_features': 'sqrt', 'min_impurity_decrease': 0.0, 'n_estimators': 100},
#   {'max_features': 'sqrt', 'min_impurity_decrease': 0.0, 'n_estimators': 250},
#   {'max_features': 'sqrt', 'min_impurity_decrease': 0.0, 'n_estimators': 500},
#   {'max_features': 'sqrt', 'min_impurity_decrease': 0.0, 'n_estimators': 1000},
#   {'max_features': 'sqrt',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 100},
#   {'max_features': 'sqrt',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 250},
#   {'max_features': 'sqrt',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 500},
#   {'max_features': 'sqrt',
#    'min_impurity_decrease': 1e-07,
#    'n_estimators': 1000}],
#  'split0_test_score': array([0.9375 , 0.9375 , 0.93125, 0.93125, 0.9375 , 0.9375 , 0.9375 ,
#         0.93125, 0.9375 , 0.9375 , 0.93125, 0.93125, 0.9375 , 0.9375 ,
#         0.9375 , 0.93125]),
#  'split1_test_score': array([0.98125, 0.9875 , 0.975  , 0.975  , 0.98125, 0.9875 , 0.98125,
#         0.975  , 0.98125, 0.9875 , 0.975  , 0.975  , 0.98125, 0.9875 ,
#         0.98125, 0.975  ]),
#  'split2_test_score': array([0.95625, 0.95625, 0.95625, 0.9625 , 0.95625, 0.95625, 0.95625,
#         0.9625 , 0.95625, 0.95625, 0.95625, 0.9625 , 0.95625, 0.95625,
#         0.95625, 0.9625 ]),
#  'split3_test_score': array([0.94375, 0.95625, 0.95625, 0.95625, 0.94375, 0.95625, 0.95625,
#         0.95625, 0.94375, 0.95625, 0.95625, 0.95625, 0.94375, 0.95625,
#         0.95625, 0.95625]),
#  'split4_test_score': array([0.96875, 0.96875, 0.9625 , 0.9625 , 0.96875, 0.975  , 0.9625 ,
#         0.9625 , 0.96875, 0.96875, 0.9625 , 0.9625 , 0.96875, 0.975  ,
#         0.9625 , 0.9625 ]),
#  'mean_test_score': array([0.9575 , 0.96125, 0.95625, 0.9575 , 0.9575 , 0.9625 , 0.95875,
#         0.9575 , 0.9575 , 0.96125, 0.95625, 0.9575 , 0.9575 , 0.9625 ,
#         0.95875, 0.9575 ]),
#  'std_test_score': array([0.01600781, 0.01648863, 0.01425219, 0.0144698 , 0.01600781,
#         0.01723006, 0.01403122, 0.0144698 , 0.01600781, 0.01648863,
#         0.01425219, 0.0144698 , 0.01600781, 0.01723006, 0.01403122,
#         0.0144698 ]),
#  'rank_test_score': array([ 7,  3, 15,  7,  7,  1,  5,  7,  7,  3, 15,  7,  7,  1,  5,  7],
#        dtype=int32)}

# %%
rgc_grid_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=1e-07, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=250,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)
